# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

import nba_api

# %%
from nba_api.stats.endpoints import playercareerstats
career = playercareerstats.PlayerCareerStats(player_id='201939')  # Example: Stephen Curry's player ID
career_df = career.season_totals_regular_season.get_data_frame()
career_df.tail()
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID  ... BLK  TOV   PF   PTS
# 12     201939   2021-22        00  1610612744  ...  23  206  130  1630
# 13     201939   2022-23        00  1610612744  ...  20  179  117  1648
# 14     201939   2023-24        00  1610612744  ...  28  210  117  1956
# 15     201939   2024-25        00  1610612744  ...  30  200   95  1718
# 16     201939   2025-26        00  1610612744  ...  17  121   75  1142
#
# [5 rows x 27 columns]
